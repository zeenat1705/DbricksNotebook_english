# %%
print("Hello Everyone")

# %%
print("Hi")

# %% [markdown]
# ########in order to push this code/notebook to github , we need to click on main icon available on top whcih will not be available on the previous notebook we created so far
